# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %% [markdown]
# # Task 1

# %%
def sigmoid(x,the):
    s = np.dot(the,x.T)
    z = 1 / (1 + np.exp(-(s))) - 0.0000001
    return z

# %%
def loss_func(x,y,the):
    m = len(x)
    y_ = sigmoid(x,the)
    return -(1/m)*np.sum(y*np.log(y_)+(1-y)*np.log(1-y_))

# %%
def grad_desc(x,y,the,l_rate,Tepochs):
    m = len(x)
    k = [loss_func(x,y,the)]
    for i in range(Tepochs):
        y_ = sigmoid(x,the)
        for i in range(0,len(x.columns)):
            the[i] -= (l_rate/m) * np.sum((y_-y)*x.iloc[:,i])
        k.append(loss_func(x,y,the))
    return k , the

# %%
def pred(x, y, the, l_rate, Tepochs):
    k, t = grad_desc(x,y,the,l_rate,Tepochs)
    y_ = sigmoid(x,the)
    for i in range(len(y_)):
        if y_[i] >= 0.5:
            y_[i] = 1
        else:
            y_[i] = 0
    y = list(y)
    accuracy = np.sum([y[i] == y_[i] for i in range(len(y))])/len(y)
    return k,accuracy

# %% [markdown]
# # Task 2

# %%
df = pd.read_csv("auto.csv")

# %%
df
# Out:
#      Unnamed: 0   mpg  cylinders  displacement  horsepower  weight  \
# 0             1  18.0          8         307.0         130    3504
# 1             2  15.0          8         350.0         165    3693
# 2             3  18.0          8         318.0         150    3436
# 3             4  16.0          8         304.0         150    3433
# 4             5  17.0          8         302.0         140    3449
# ..          ...   ...        ...           ...         ...     ...
# 387         393  27.0          4         140.0          86    2790
# 388         394  44.0          4          97.0          52    2130
# 389         395  32.0          4         135.0          84    2295
# 390         396  28.0          4         120.0          79    2625
# 391         397  31.0          4         119.0          82    2720
#
#      acceleration  year  origin                       name
# 0            12.0    70       1  chevrolet chevelle malibu
# ...

# %%
high = df['mpg']
h = []

# %%
for i in high:
    if i>= 23:
        h.append(1)
    else:
        h.append(0)
high2 = pd.DataFrame(h, columns = ['mpg'])

# %%
df['mpg'] = high2

# %%
df_copy = df.copy()

# %%
df_copy
# Out:
#      Unnamed: 0  mpg  cylinders  displacement  horsepower  weight  \
# 0             1    0          8         307.0         130    3504
# 1             2    0          8         350.0         165    3693
# 2             3    0          8         318.0         150    3436
# 3             4    0          8         304.0         150    3433
# 4             5    0          8         302.0         140    3449
# ..          ...  ...        ...           ...         ...     ...
# 387         393    1          4         140.0          86    2790
# 388         394    1          4          97.0          52    2130
# 389         395    1          4         135.0          84    2295
# 390         396    1          4         120.0          79    2625
# 391         397    1          4         119.0          82    2720
#
#      acceleration  year  origin                       name
# 0            12.0    70       1  chevrolet chevelle malibu
# ...

# %%
dummy_var = ['origin']

# %%
df_copy = pd.get_dummies(df_copy, columns = dummy_var)
print(df_copy.columns)
# Out:
# Index(['Unnamed: 0', 'mpg', 'cylinders', 'displacement', 'horsepower',
#        'weight', 'acceleration', 'year', 'name', 'origin_1', 'origin_2',
#        'origin_3'],
#       dtype='object')

# %%
df_copy.rename(columns={"mpg":"High"})
# Out:
#      Unnamed: 0  High  cylinders  displacement  horsepower  weight  \
# 0             1     0          8         307.0         130    3504
# 1             2     0          8         350.0         165    3693
# 2             3     0          8         318.0         150    3436
# 3             4     0          8         304.0         150    3433
# 4             5     0          8         302.0         140    3449
# ..          ...   ...        ...           ...         ...     ...
# 387         393     1          4         140.0          86    2790
# 388         394     1          4          97.0          52    2130
# 389         395     1          4         135.0          84    2295
# 390         396     1          4         120.0          79    2625
# 391         397     1          4         119.0          82    2720
#
#      acceleration  year                       name  origin_1  origin_2  \
# 0            12.0    70  chevrolet chevelle malibu         1         0
# ...

# %%
df_copy = pd.concat([pd.Series(1, index = df.index, name = '00'), df_copy],axis=1)

# %%
X = df_copy.drop(columns =["Unnamed: 0","cylinders","displacement","acceleration","name","mpg"])
X.rename(columns={"mpg":"High"})
# Out:
#      00  horsepower  weight  year  origin_1  origin_2  origin_3
# 0     1         130    3504    70         1         0         0
# 1     1         165    3693    70         1         0         0
# 2     1         150    3436    70         1         0         0
# 3     1         150    3433    70         1         0         0
# 4     1         140    3449    70         1         0         0
# ..   ..         ...     ...   ...       ...       ...       ...
# 387   1          86    2790    82         1         0         0
# 388   1          52    2130    82         0         1         0
# 389   1          84    2295    82         1         0         0
# 390   1          79    2625    82         1         0         0
# 391   1          82    2720    82         1         0         0
#
# [392 rows x 7 columns]

# %%
y = df["mpg"]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 387    1
# 388    1
# 389    1
# 390    1
# 391    1
# Name: mpg, Length: 392, dtype: int64

# %%
normalized_X = preprocessing.normalize(X)

# %%
X
# Out:
#      00  horsepower  weight  year  origin_1  origin_2  origin_3
# 0     1         130    3504    70         1         0         0
# 1     1         165    3693    70         1         0         0
# 2     1         150    3436    70         1         0         0
# 3     1         150    3433    70         1         0         0
# 4     1         140    3449    70         1         0         0
# ..   ..         ...     ...   ...       ...       ...       ...
# 387   1          86    2790    82         1         0         0
# 388   1          52    2130    82         0         1         0
# 389   1          84    2295    82         1         0         0
# 390   1          79    2625    82         1         0         0
# 391   1          82    2720    82         1         0         0
#
# [392 rows x 7 columns]

# %% [markdown]
# # Task 3

# %%
x_train,x_test,y_test,y_train = train_test_split(X,y,random_state = 236,test_size = 0.5)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (196, 7)
# (196, 7)
# (196,)
# (196,)

# %% [markdown]
# # Task 4

# %%
the = [0.3]*len(x_train.columns)
k , accuracy = pred(x_train,y_train,the,0.001,100)
print(accuracy)
# Out:
# 0.5357142857142857

# %%
the = [-0.5]*len(x_train.columns)
k , accuracy = pred(x_train,y_train,the,0.00001,200)
print(accuracy)
# Out:
# <ipython-input-2-06f83893ab04>:3: RuntimeWarning: overflow encountered in exp
#   z = 1 / (1 + np.exp(-(s))) - 0.0000001
# <ipython-input-3-7319db5e8e96>:4: RuntimeWarning: invalid value encountered in log
#   return -(1/m)*np.sum(y*np.log(y_)+(1-y)*np.log(1-y_))
# 0.4642857142857143

# %%
the = [0.6]*len(x_test.columns)
k , accuracy = pred(x_test,y_test,the,0.01,15000)
print(accuracy)
# Out:
# 0.4642857142857143
